# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import re
import math
import glob
import pandas as pd

class SplitArray:
    def __init__(self, array, m):
        self.array = array
        self.m = m
        self.n = len(array)
        self.chunk_size = self.n // m
        self.remainder = self.n % m

    def __getitem__(self, index):
        if index >= self.m or index < -self.m:
            raise IndexError("Split index out of range")

        if index < 0:
            index += self.m

        start = index * self.chunk_size + min(index, self.remainder)
        end = start + self.chunk_size
        if index < self.remainder:
            end += 1
        return self.array[start:end]

    def __len__(self):
        return self.m

cs = math.sqrt(3.36) * 100
bvec = np.logspace(9, 17, 80)
Nv = 30
vvec = np.logspace(np.log10(cs / 10), np.log10(cs * 5), Nv)

folder = './ShuEnergies'
energies = sorted(os.listdir(folder))
Efinal = []

for e in energies:
    path = os.path.join(folder, e)
    evec = np.loadtxt(path)

    pattern = r"v(\d+)b(\d+)"

    match = re.search(pattern, e)

    if match:
        v_index = int(match.group(1))
        b_index = int(match.group(2))
    else:
        print("No match found")

    v0 = vvec[v_index]

    if evec.size == 0:
            continue

    if evec.size == 1:
        Efinal.append([evec])
        continue

    Efinal.append(evec)

Efinal = np.concatenate(Efinal)

plt.clf()
plt.ylabel(r'$\Delta E$')
plt.scatter(range(len(Efinal)), Efinal, s=1)
plt.yscale('symlog')
plt.show()
# Out:
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b0.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b12.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b19.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b2.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b21.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b27.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b33.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b36.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b37.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b48.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b49.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b50.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b51.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b53.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b57.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b60.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b63.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b14.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b2.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b3.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b34.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b4.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b42.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b53.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b54.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b55.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b56.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b61.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b65.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b66.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b10.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b14.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b2.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b24.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b26.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b27.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b35.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b36.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b43.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b46.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b52.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b54.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b57.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b63.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b67.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b68.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b11.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b13.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b20.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b25.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b26.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b27.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b33.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b4.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b42.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b45.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b50.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b53.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b54.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b57.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b62.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b63.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b64.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b67.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b68.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b9.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b0.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b10.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b11.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b14.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b15.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b18.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b24.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b26.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b31.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b32.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b33.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b4.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b49.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b50.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b51.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b52.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b55.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b57.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b58.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b6.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b61.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b65.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b67.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b68.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b8.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b9.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b1.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b11.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b13.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b20.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b35.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b41.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b42.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b44.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b46.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b49.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b52.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b57.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b59.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b60.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b63.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b65.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b67.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b68.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b0.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b1.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b12.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b2.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b22.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b24.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b25.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b32.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b35.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b36.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b4.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b45.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b48.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b5.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b50.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b51.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b53.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b56.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b57.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b61.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b63.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b65.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b66.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b67.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b68.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b7.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b0.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b16.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b2.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b22.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b23.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b24.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b25.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b32.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b33.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b36.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b40.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b41.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b44.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b46.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b52.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b57.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b64.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b65.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b66.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b67.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b68.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b16.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b18.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b26.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b3.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b32.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b34.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b35.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b40.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b5.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b51.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b55.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b60.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b61.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b65.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b66.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b67.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b68.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v18b0.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v18b1.txt"
#   evec = np.loadtxt(path)
# ...
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b21.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b23.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b24.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b30.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b4.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b41.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b42.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b43.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b44.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b49.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b51.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b55.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b56.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b61.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b64.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b67.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b15.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b17.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b30.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b34.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b35.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b41.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b45.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b47.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b53.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b54.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b60.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b61.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b67.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b68.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b9.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b10.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b14.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b19.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b2.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b23.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b29.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b3.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b30.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b31.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b35.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b38.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b40.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b42.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b43.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b44.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b46.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b47.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b50.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b53.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b54.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b57.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b58.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b64.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b65.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b67.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b68.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_68642/3611714096.py:44: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b9.txt"
#   evec = np.loadtxt(path)

# %%
# %matplotlib widget

def log_histogram(data, bins):
    data = np.array(data)
    positive_data = data[data > 0]
    negative_data = -data[data < 0]

    min_val = min(positive_data.min(), negative_data.min())
    max_val = max(positive_data.max(), negative_data.max())

    log_bins = np.logspace(np.log10(min_val), np.log10(max_val), num=bins+1)

    neg_bins = -log_bins[::-1]
    all_bins = np.concatenate([neg_bins, [0], log_bins])

    counts, edges = np.histogram(data, bins=all_bins)

    plt.figure(figsize=(8, 5))
    plt.hist(data, bins=all_bins, histtype='step')

log_histogram(Efinal, bins=30)
plt.xscale('symlog', linthresh=1e-3)
plt.yscale('log')
plt.xlabel(r'$\Delta E$ $\left(\frac{m^2}{s^2}\right)$')
plt.ylabel('Counts')
plt.title('Change In Energy Frequency')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import pandas as pd
import os
import numpy as np
import fast_histogram as fh
import matplotlib.pyplot as plt
import re
import math

plt.clf()
cs = math.sqrt(3.36) * 100
bvec = np.logspace(9, 17, 80)
Nv = 30
vvec = np.logspace(np.log10(cs / 10), np.log10(cs * 5), Nv)
tf = 1.0829*10.0**13 #s

V = {}

def captureVol(dir_path):
    V = {}
    bmax = 0

    dir_re  = re.compile(r"ShuEnergies$")
    file_re = re.compile(r"v(\d+)b(\d+)\.txt")

    def sort_key(fname):
        m = file_re.match(fname)
        if not m:
            return (1e9, 1e9)
        v_i, b_i = map(int, m.groups())
        return (v_i, b_i)

    dirname = os.path.basename(dir_path.rstrip('/'))
    
    '''
    dm = dir_re.match(dirname)

    if not dm:
        raise ValueError(f"Directory name {dirname!r} does not match dataShu<digits>")
    
    folder_index = int(dm.group(1))
    '''
    
    for v in vvec:
        V[str(v)] = []

    bvec = bvec = np.logspace(9, 17, 80)

    for fname in sorted(os.listdir(dir_path), key=sort_key):
        if not fname.endswith('.txt'):
            continue

        fpath = os.path.join(dir_path, fname)
        if os.path.getsize(fpath) == 0:
            continue
        data  = np.loadtxt(fpath)
        
        fm = file_re.match(fname)
        if not fm:
            print(f"  skipping unexpected file {fname!r}")
            continue

        v_index = int(fm.group(1))
        b_index = int(fm.group(2))

        Ncapt = 0

        if data.size == 0:
                continue
        if data.size == 1:
            if data<0:
                Ncapt += 1
            else:
                continue
        if data.size > 1:
            for e in data:
                if e < 0 :
                    Ncapt += 1
                else:
                    continue
        
        Vcapture = np.pi*Ncapt*(bvec[b_index+1]**2-bvec[b_index]**2)*vvec[v_index]*tf/50
        V[f'{vvec[v_index]}'].append(Vcapture)

    Vcapture = []
    for v in V.keys():
        Vtot = np.sum(np.array(V[f'{v}']))
        Vcapture.append([f'{v}', Vtot])

    v0 = np.array([float(Vcapture[i][0]) for i in range(len(Vcapture))])
    Vvol = np.array([Vcapture[i][1]/((1.496e11)**3) for i in range(len(Vcapture))])

    plt.plot(v0, Vvol)
    plt.yscale('log')
    plt.xscale('log')
    plt.xlabel(r'$v_0$ (m/s)')
    plt.ylabel(r'$V_{\mathrm{capture}}$ (AU$^3$)')
        

captureVol('./ShuEnergies')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
