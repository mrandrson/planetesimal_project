# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from fast_histogram import histogram1d

folder = './ShuEnergies'
energies = sorted(os.listdir(folder))
Efinal = []

for e in energies:
    path = os.path.join(folder, e)
    evec = np.loadtxt(path)

    if evec.size == 0:
        #print(f"Skipped empty file: {e}")
        continue

    if evec.size == 1:
        Efinal.append(evec)
        continue

    Efinal.append(evec[-1]-evec[0])

plt.clf()
plt.ylabel(r'$\Delta E$')
plt.scatter(range(len(Efinal)), Efinal, s=1)
plt.yscale('symlog')
plt.show()
# Out:
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b0.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b10.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b11.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b12.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b13.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b17.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b2.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b20.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b24.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b26.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b29.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b34.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b35.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b36.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b4.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b41.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b5.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b53.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b57.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b58.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b59.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b6.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b60.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b63.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b66.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v0b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b13.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b22.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b30.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b31.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b32.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b44.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b45.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b53.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b57.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b61.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b64.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b68.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v10b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b0.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b11.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b12.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b19.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b21.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b31.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b33.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b37.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b39.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b55.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b67.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b68.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v11b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b27.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b31.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b33.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b35.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b37.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b44.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b45.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b46.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b55.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b57.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b64.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b66.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b67.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b68.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v12b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b12.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b22.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b24.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b27.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b3.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b46.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b58.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b60.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b61.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b62.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b63.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b65.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b66.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b67.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b68.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v13b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b1.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b10.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b12.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b15.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b23.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b25.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b29.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b3.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b35.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b39.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b40.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b43.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b47.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b5.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b55.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b62.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b64.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b65.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b66.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b67.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b68.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b8.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v14b9.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b0.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b11.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b12.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b15.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b29.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b30.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b44.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b45.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b47.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b52.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b54.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b56.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b58.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b59.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b60.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b61.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b62.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b63.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b64.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b65.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b66.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b67.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b68.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b7.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v15b8.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b0.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b1.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b10.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b11.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b12.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b15.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b25.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b29.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b33.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b34.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b35.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b45.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b48.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b49.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b50.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b51.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b54.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b55.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b57.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b58.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b59.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b6.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b60.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b63.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b65.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b66.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b67.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b68.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v16b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b1.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b11.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b15.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b24.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b28.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b33.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b35.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b36.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b40.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b43.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b46.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b47.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b5.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b62.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b65.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b66.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b67.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b68.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v17b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v18b0.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v18b15.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v18b16.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v18b17.txt"
#   evec = np.loadtxt(path)
# ...
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v6b57.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v6b64.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v6b66.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v6b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v6b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v6b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v6b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v6b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v6b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v6b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v6b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v6b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v6b8.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b0.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b13.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b26.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b30.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b31.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b34.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b40.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b5.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b65.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b66.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b68.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b7.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v7b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b0.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b11.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b21.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b25.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b32.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b33.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b34.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b36.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b38.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b4.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b41.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b54.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b55.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b56.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b57.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v8b8.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b10.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b15.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b16.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b18.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b2.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b24.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b27.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b31.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b33.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b41.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b45.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b48.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b55.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b65.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b68.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b69.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b70.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b71.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b72.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b73.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b74.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b75.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b76.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b77.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b78.txt"
#   evec = np.loadtxt(path)
# /var/folders/rd/thp_lwbs14n9hkhhc4r29lfw0000gn/T/ipykernel_72777/1216966996.py:12: UserWarning: loadtxt: input contained no data: "./ShuEnergies/v9b8.txt"
#   evec = np.loadtxt(path)

# %%
def log_histogram(data, bins):
    data = np.array(data)
    positive_data = data[data > 0]
    negative_data = -data[data < 0]

    min_val = min(positive_data.min(), negative_data.min())
    max_val = max(positive_data.max(), negative_data.max())

    log_bins = np.logspace(np.log10(min_val), np.log10(max_val), num=bins+1)

    neg_bins = -log_bins[::-1]
    all_bins = np.concatenate([neg_bins, [0], log_bins])

    counts, edges = np.histogram(data, bins=all_bins)

    plt.figure(figsize=(8, 5))
    plt.hist(data, bins=all_bins, histtype='step')

log_histogram(E_all_flat, bins=30)
plt.xscale('symlog', linthresh=1e1)
plt.yscale('log')
plt.xlabel(r'Energy $\left(\frac{m^2}{s^2}\right)$')
plt.ylabel('Counts')
plt.title('Individual Energy Datapoint Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 19
#      16     plt.figure(figsize=(8, 5))
#      17     plt.hist(data, bins=all_bins, histtype='step')
# ---> 19 log_histogram(E_all_flat, bins=30)
#      20 plt.xscale('symlog', linthresh=1e1)
#      21 plt.yscale('log')
#
# NameError: name 'E_all_flat' is not defined

# %%
# %matplotlib widget
log_histogram(Efinal, bins=30)
plt.xscale('symlog', linthresh=1e1)
plt.yscale('log')
plt.xlabel(r'$\Delta E$ $\left(\frac{m^2}{s^2}\right)$')
plt.ylabel('Counts')
plt.title('Change In Energy Frequency')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
